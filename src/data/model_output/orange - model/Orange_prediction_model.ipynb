# %%
import pandas as pd

df = pd.read_csv(
    'orange_power_forecast_2022_daily.csv')

df.head()
# Out:
#          date Random Forest avg_wind_speed_all_stations  \
# 0        time    continuous                  continuous
# 1        meta          meta                         NaN
# 2  2022-01-01   2.53953e+07                     7.05442
# 3  2022-01-02    4.2542e+07                     9.18525
# 4  2022-01-03    4.2318e+07                     9.25733
#
#   vector_avg_wind_speed_all_stations avg_wind_direction avg_wind_speed_cubed
# 0                         continuous         continuous           continuous
# 1                                NaN                NaN                  NaN
# 2                            6.85321            210.831              351.062
# 3                            8.86637            229.843              774.949
# 4                            9.19753            237.868              793.337

# %%
df = df[['date', 'Random Forest']]
df = df.drop(index=[0, 1]).reset_index(drop=True)

df.head()
# Out:
#          date Random Forest
# 0  2022-01-01   2.53953e+07
# 1  2022-01-02    4.2542e+07
# 2  2022-01-03    4.2318e+07
# 3  2022-01-04   2.03423e+07
# 4  2022-01-05   3.79007e+07

# %%
df = df.rename(columns={'Random Forest': 'Orange Model - Predicted Wind Power (kWh)'})
df['Orange Model - Predicted Wind Power (kWh)'] = df['Orange Model - Predicted Wind Power (kWh)'].astype(float).astype(int)

df.head(10)
# Out:
#          date  Orange Model - Predicted Wind Power (kWh)
# 0  2022-01-01                                   25395300
# 1  2022-01-02                                   42542000
# 2  2022-01-03                                   42318000
# 3  2022-01-04                                   20342300
# 4  2022-01-05                                   37900700
# 5  2022-01-06                                   11895500
# 6  2022-01-07                                   24560000
# 7  2022-01-08                                   22984200
# 8  2022-01-09                                   23374400
# 9  2022-01-10                                    2625550

# %%
output_path = 'orange_power_forecast_2022_daily_clean.csv'
df.to_csv(output_path, index=False)

print(f'Saved {len(df)} rows to {output_path}')
# Out:
# Saved 365 rows to orange_power_forecast_2022_daily_clean.csv

# %%
df
# Out:
#            date  Orange Model - Predicted Wind Power (kWh)
# 0    2022-01-01                                   25395300
# 1    2022-01-02                                   42542000
# 2    2022-01-03                                   42318000
# 3    2022-01-04                                   20342300
# 4    2022-01-05                                   37900700
# ..          ...                                        ...
# 360  2022-12-27                                   29188200
# 361  2022-12-28                                   62617000
# 362  2022-12-29                                   66959500
# 363  2022-12-30                                   49984200
# 364  2022-12-31                                   71901600
#
# [365 rows x 2 columns]
